# %% [markdown]
# <a href="https://colab.research.google.com/github/KrRishabh/Python-for-deep-learning/blob/main/Python_for_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

plt.plot(3,4, 'o')

# %%
x = [0,1]
y = [1,3]
plt.plot(x,y,'m')
plt.show()
